# %%
from serieDeTiempoAccion import crearGrafico
import os

# %%
ruta = '/home/jose/Documentos/bd/stocks/full_history'

# %%
listaDeAcciones =  sorted([".".join(a.split('.')[:-1]) for a in os.listdir(ruta)])

# %%
for accion in listaDeAcciones:
    crearGrafico(accion)
# Out:
# No hay suficientes datos
# No se puede generar gráfico
# No hay suficientes datos
# No se puede generar gráfico
# Gráfico de la acción AAAU generado exitosamente
# Gráfico de la acción AACG generado exitosamente
# Gráfico de la acción AADR generado exitosamente
# Gráfico de la acción AAL generado exitosamente
# Gráfico de la acción AAMC generado exitosamente
# Gráfico de la acción AAME generado exitosamente
# Gráfico de la acción AAN generado exitosamente
# Gráfico de la acción AAOI generado exitosamente
# Gráfico de la acción AAON generado exitosamente
# Gráfico de la acción AAP generado exitosamente
# Gráfico de la acción AAPL generado exitosamente
# Gráfico de la acción AAT generado exitosamente
# Gráfico de la acción AAU generado exitosamente
# Gráfico de la acción AAWW generado exitosamente
# Gráfico de la acción AAXJ generado exitosamente
# No hay suficientes datos
# No se puede generar gráfico
# Gráfico de la acción AB generado exitosamente
# ...
